# %% [markdown]
# #               <center>Viewership Analysis</center>

# %% [markdown]
# ### <center>[Sachin Singh]</center>

# %% [markdown]
# # Introduction

# %% [markdown]
# There are two types of data for each TV show.
# The first one is Barch history data, which contain impressions(how many people were watching that show) at every minute level.
# The second data , which contain whether a character is present in the show or not at every second level.

# %%
cd C:\Users\sachin\Downloads
# Out:
# C:\Users\sachin\Downloads

# %% [markdown]
# #### Barc History Data

# %%
import pandas as pd
import numpy as np
barc_data = pd.read_csv("history_barc.csv")
barc_data
# Out:
#           upload_date  year_week_id  impressions mkt_type  TGM_Type Channel  \
# 0      09-01-19 13:00        201848    572.35999      HSM  Universe  Colors
# 1      09-01-19 13:00        201848    662.85999      HSM  Universe  Colors
# 2      09-01-19 13:00        201848    686.91998      HSM  Universe  Colors
# 3      09-01-19 13:00        201848    688.34998      HSM  Universe  Colors
# 4      09-01-19 13:00        201848    642.64001      HSM  Universe  Colors
# 5      09-01-19 13:00        201848    607.71002      HSM  Universe  Colors
# 6      09-01-19 13:00        201848    686.09998      HSM  Universe  Colors
# 7      09-01-19 13:00        201848    700.73999      HSM  Universe  Colors
# 8      09-01-19 13:00        201848    472.17999      HSM  Universe  Colors
# 9      09-01-19 13:00        201848    439.60001      HSM  Universe  Colors
# 10     09-01-19 13:00        201848    424.29001      HSM  Universe  Colors
# ...

# %% [markdown]
# #### Character presence data (second level)

# %%
characters=pd.read_csv("channel_2_29_30_22_24_show_2130_2200 (1).csv")
characters
# Out:
#         ao_date_id  Channel_id  Channel_name      date timestamp  Video_time  \
# 0           181231          29           NaN  31-12-18  21:30:06           0
# 1           181231          29           NaN  31-12-18  21:30:07           1
# 2           181231          29           NaN  31-12-18  21:30:08           2
# 3           181231          29           NaN  31-12-18  21:30:09           3
# 4           181231          29           NaN  31-12-18  21:30:10           4
# 5           181231          29           NaN  31-12-18  21:30:11           5
# 6           181231          29           NaN  31-12-18  21:30:12           6
# 7           181231          29           NaN  31-12-18  21:30:13           7
# 8           181231          29           NaN  31-12-18  21:30:14           8
# 9           181231          29           NaN  31-12-18  21:30:15           9
# 10          181231          29           NaN  31-12-18  21:30:16          10
# ...

# %% [markdown]
# data of impressions section wise

# %% [markdown]
# # channel - ZEE TV, Time Slot- 21:30

# %% [markdown]
# ### impression plots w.r.t time(normalised)

# %%
from IPython.display import display, Image
path1 = "plot_images_for_impressions\impressions_curve_ch2_s1_1day.jpg"
path2 = "plot_images_for_impressions\impressions_curve_ch2_s1_entireData.jpg"
path3 = "plot_images_for_impressions\impressions_curve_ch2_s1_1day_entire_data_overlaped.jpg"
path4 = "plot_images_for_impressions\impressions_curve_ch2_s2_1day.jpg"
path5 = "plot_images_for_impressions\impressions_curve_ch2_s2_entireData.jpg"
path6 = "plot_images_for_impressions\impressions_curve_ch2_s2_1day_entire_data_overlaped.jpg"
path7 = "plot_images_for_impressions\impressions_curve_ch2_s3_1day.jpg"
path8 = "plot_images_for_impressions\impressions_curve_ch2_s3_entireData.jpg"
path9 = "plot_images_for_impressions\impressions_curve_ch2_s3_1day_entire_data_overlaped.jpg"
for path in path1, path2,path3,path4,path5,path6,path7,path8,path9:
    img = Image(path)
    display(img)

# %% [markdown]
# # channel - Colors, Time Slot- 21:30

# %% [markdown]
# ### impression plots w.r.t time(normalised)

# %%
from IPython.display import display, Image
path1 = "plot_images_for_impressions\impressions_curve_ch3_s1_1day.jpg"
path2 = "plot_images_for_impressions\impressions_curve_ch3_s1_entireData.jpg"
path3 = "plot_images_for_impressions\impressions_curve_ch3_s1_1day_entire_data_overlaped.jpg"
path4 = "plot_images_for_impressions\impressions_curve_ch3_s2_1day.jpg"
path5 = "plot_images_for_impressions\impressions_curve_ch3_s2_entireData.jpg"
path6 = "plot_images_for_impressions\impressions_curve_ch3_s2_1day_entire_data_overlaped.jpg"

for path in path1, path2,path3,path4,path5,path6:
    img = Image(path)
    display(img)

# %% [markdown]
# # channel - Sony Entertainment Television, Time Slot- 21:30

# %% [markdown]
# ### impression plots w.r.t time(normalised)

# %%
from IPython.display import display, Image
path1 = "plot_images_for_impressions\impressions_curve_ch4_s1_1day.jpg"
path2 = "plot_images_for_impressions\impressions_curve_ch4_s1_entireData.jpg"
path3 = "plot_images_for_impressions\impressions_curve_ch4_s1_1day_entire_data_overlaped.jpg"
path4 = "plot_images_for_impressions\impressions_curve_ch4_s2_1day.jpg"
path5 = "plot_images_for_impressions\impressions_curve_ch4_s2_entireData.jpg"
path6 = "plot_images_for_impressions\impressions_curve_ch4_s2_1day_entire_data_overlaped.jpg"
path7 = "plot_images_for_impressions\impressions_curve_ch4_s3_1day.jpg"
path8 = "plot_images_for_impressions\impressions_curve_ch4_s3_entireData.jpg"
path9 = "plot_images_for_impressions\impressions_curve_ch4_s3_1day_entire_data_overlaped.jpg"
for path in path1, path2,path3,path4,path5,path6,path7,path8,path9:
    img = Image(path)
    display(img)

# %% [markdown]
# # channel - Star Plus, Time Slot- 21:30

# %% [markdown]
# ### impression plots w.r.t time(normalised)

# %%
from IPython.display import display, Image
path1 = "plot_images_for_impressions\impressions_curve_ch1_s1_1day.jpg"
path2 = "plot_images_for_impressions\impressions_curve_ch1_s1_entireData.jpg"
path3 = "plot_images_for_impressions\impressions_curve_ch1_s1_1day_entire_data_overlaped.jpg"
path4 = "plot_images_for_impressions\impressions_curve_ch1_s2_1day.jpg"
path5 = "plot_images_for_impressions\impressions_curve_ch1_s2_entireData.jpg"
path6 = "plot_images_for_impressions\impressions_curve_ch1_s2_1day_entire_data_overlaped.jpg"
path7 = "plot_images_for_impressions\impressions_curve_ch1_s3_1day.jpg"
path8 = "plot_images_for_impressions\impressions_curve_ch1_s3_entireData.jpg"
path9 = "plot_images_for_impressions\impressions_curve_ch1_s3_1day_entire_data_overlaped.jpg"
for path in path1, path2,path3,path4,path5,path6,path7,path8,path9:
    img = Image(path)
    display(img)

# %% [markdown]
# # Combined data of impressions and audio profile

# %%
combine_data=pd.read_csv("impression_data/combine_data.csv")

# %%
combine_data
# Out:
#       Channel_id      date       timestamp  ao_date_id  Normal Speech  \
# 0              2  26-11-18  01-01-00 21:30    10867560             54
# 1              2  26-11-18  01-01-00 21:31    10867560             54
# 2              2  26-11-18  01-01-00 21:32    10505308             21
# 3              2  26-11-18  01-01-00 21:33    10867560             33
# 4              2  26-11-18  01-01-00 21:34    10867560             44
# 5              2  26-11-18  01-01-00 21:35    10686434             35
# 6              2  26-11-18  01-01-00 21:36    10867560             43
# 7              2  26-11-18  01-01-00 21:37    10867560             37
# 8              2  26-11-18  01-01-00 21:38    10867560             40
# 9              2  26-11-18  01-01-00 21:39    10867560             42
# 10             2  26-11-18  01-01-00 21:40    10867560             44
# 11             2  26-11-18  01-01-00 21:41    10686434             46
# ...
